# %% [markdown]
# ---
# title: "Untitled"
# format: html
# fig-width: 2
# fig-height: 5
# fig-format: svg
# keep-ipynb: true
# ---

# %%
from plotnine import ggplot, aes, geom_point, labs, options
from plotnine.data import penguins

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

data = np.random.randn(50)
plt.plot(data)

# %%
with mpl.rc_context({'figure.figsize': (12, 3)}):
    plt.plot(data)

# %%
#| label: format-pdf
# This doesn't work
mpl.rcParams['savefig.format'] = 'pdf'
plt.plot(data)

# %%
#| label: plotnine

options.figure_format = 'svg'
(
    ggplot(penguins, aes("bill_length_mm", "bill_depth_mm", color="species"))
    + geom_point() 
)

# %%
#| label: ipython-pdf
# %config InlineBackend.figure_formats = ['pdf']

plt.plot(data)
