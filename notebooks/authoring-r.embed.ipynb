# %% [markdown]
# # Authoring - R
#
# ## Markdown text
#
# hello
#
# ## Code cells

# %%
#| label: add

1 + 1
# Out:
# [1] 2

# %%
#| label: plot

df <- data.frame(x = 1:8, y = 3:10)
m <- lm(y ~ x, data = df)
plot(df$x, df$y)
abline(m)
