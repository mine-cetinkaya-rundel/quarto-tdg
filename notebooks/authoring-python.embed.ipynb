# %% [markdown]
# # Authoring - Python

# %% [markdown]
# ## Markdown text
#
# ## Code cells

# %%
#| label: add
1 + 1
# Out:
# 2

# %%
#| label: plot
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()
